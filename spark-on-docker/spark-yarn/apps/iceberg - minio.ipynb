# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
            .appName('Iceberg - minio') \
            .config("spark.executor.memory", "1G") \
            .config("spark.driver.memory", "1G") \
            .config("spark.driver.maxResultSize", "1G") \
            .config("spark.jars.packages", "org.apache.hadoop:hadoop-aws:3.4.0,org.apache.iceberg:iceberg-spark-runtime-3.5_2.12:1.6.0") \
            .config("spark.hadoop.fs.s3a.endpoint", "http://minio:9000") \
            .config("spark.hadoop.fs.s3a.access.key", "myuserserviceaccount") \
            .config("spark.hadoop.fs.s3a.secret.key", "myuserserviceaccountpassword") \
            .config("spark.hadoop.fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem") \
            .config("spark.hadoop.fs.s3a.path.style.access", "true") \
            .config("spark.sql.extensions", "org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions") \
            .config("spark.sql.catalog.iceberg_catalog", "org.apache.iceberg.spark.SparkCatalog") \
            .config("spark.sql.catalog.iceberg_catalog.type", "hadoop") \
            .config("spark.sql.catalog.iceberg_catalog.warehouse", "s3a://my-bucket/iceberg") \
            .config("spark.sql.defaultCatalog", "iceberg_catalog") \
            .getOrCreate()

spark.sparkContext.setLogLevel("ERROR")
spark
# Out:
# :: loading settings :: url = jar:file:/opt/spark-3.5.1-bin-without-hadoop/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /root/.ivy2/cache
# The jars for the packages stored in: /root/.ivy2/jars
# org.apache.hadoop#hadoop-aws added as a dependency
# org.apache.iceberg#iceberg-spark-runtime-3.5_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-53e0c844-0fe1-436e-8f5c-2035cd260988;1.0
# 	confs: [default]
# 	found org.apache.hadoop#hadoop-aws;3.4.0 in central
# 	found software.amazon.awssdk#bundle;2.23.19 in central
# 	found org.wildfly.openssl#wildfly-openssl;1.1.3.Final in central
# 	found org.apache.iceberg#iceberg-spark-runtime-3.5_2.12;1.6.0 in central
# :: resolution report :: resolve 127ms :: artifacts dl 3ms
# 	:: modules in use:
# 	org.apache.hadoop#hadoop-aws;3.4.0 from central in [default]
# 	org.apache.iceberg#iceberg-spark-runtime-3.5_2.12;1.6.0 from central in [default]
# 	org.wildfly.openssl#wildfly-openssl;1.1.3.Final from central in [default]
# 	software.amazon.awssdk#bundle;2.23.19 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   4   |   0   |   0   |   0   ||   4   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-53e0c844-0fe1-436e-8f5c-2035cd260988
# 	confs: [default]
# 	0 artifacts copied, 4 already retrieved (0kB/3ms)
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://localhost:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Iceberg - minio</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
bucket = "my-bucket"

# %% [markdown]
# ## Dataframe creation

# %%
from datetime import datetime

from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DateType
from pyspark.sql.functions import lit, col
from delta.tables import DeltaTable

# %%
data =  [{'id': 1, 'name': 'Alice', 'updated_at': datetime(2022, 1, 1)},
         {'id': 2, 'name': 'Braga', 'updated_at': datetime(2022, 2, 2)},
         {'id': 3, 'name': 'Steve', 'updated_at': datetime(2022, 3, 3)}]

schema = StructType([StructField('id', IntegerType(), nullable=True),
                     StructField('name', StringType(), nullable=True),
                     StructField('updated_at', DateType(), nullable=True)])

df = spark.createDataFrame(data, schema=schema)
df.toPandas()
# Out:
#    id   name  updated_at
# 0   1  Alice  2022-01-01
# 1   2  Braga  2022-02-02
# 2   3  Steve  2022-03-03

# %% [markdown]
# # Create Iceberg Table from DF

# %%
spark.sql("show catalogs").toPandas()
# Out:
#            catalog
# 0  iceberg_catalog
# 1    spark_catalog

# %%
spark.catalog.listCatalogs()
# Out:
# [CatalogMetadata(name='iceberg_catalog', description=None),
#  CatalogMetadata(name='spark_catalog', description=None)]

# %%
spark.catalog.currentCatalog()
# Out:
# 'iceberg_catalog'

# %%
# create database/namespace
spark.sql("CREATE NAMESPACE IF NOT EXISTS mydb").toPandas()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
spark.sql("show databases").toPandas()
# Out:
#   namespace
# 0      mydb

# %%
spark.catalog.listDatabases()
# Out:
# [Database(name='mydb', catalog='iceberg_catalog', description=None, locationUri='s3a://my-bucket/iceberg/mydb')]

# %%
spark.sql("describe database mydb").toPandas()
# Out:
#         info_name                    info_value
# 0    Catalog Name               iceberg_catalog
# 1  Namespace Name                          mydb
# 2        Location  s3a://my-bucket/iceberg/mydb

# %%
spark.sql(f"""
CREATE TABLE IF NOT EXISTS mydb.users (
    id INT COMMENT 'Identificador único',
    name STRING COMMENT 'Nome do indivíduo',
    updated_at date COMMENT 'Data de update'
)
USING iceberg
""")
# location 's3a://{bucket}/iceberg/db/users'  -- no need of it
# Out:
# DataFrame[]

# %%
spark.sql("show tables in mydb").toPandas()
# Out:
#   namespace tableName  isTemporary
# 0      mydb     users        False

# %%
spark.sql("""
    describe table extended mydb.users
""").toPandas()
# Out:
#                         col_name  \
# 0                             id
# 1                           name
# 2                     updated_at
# 3
# 4             # Metadata Columns
# 5                       _spec_id
# 6                     _partition
# 7                          _file
# 8                           _pos
# 9                       _deleted
# 10
# 11  # Detailed Table Information
# 12                          Name
# 13                          Type
# 14                      Location
# 15                      Provider
# 16                         Owner
# 17              Table Properties
#
#                                             data_type              comment
# 0                                                 int  Identificador único
# 1                                              string    Nome do indivíduo
# 2                                                date       Data de update
# 3
# 4
# 5                                                 int
# 6                                            struct<>
# 7                                              string
# 8                                              bigint
# 9                                             boolean
# 10
# 11
# 12                         iceberg_catalog.mydb.users
# 13                                            MANAGED
# 14                 s3a://my-bucket/iceberg/mydb/users
# 15                                            iceberg
# 16                                               root
# 17  [current-snapshot-id=none,format=iceberg/parqu...

# %%
df.writeTo("mydb.users").append()

# %%
spark.read.table("mydb.users").toPandas()
# Out:
#    id   name  updated_at
# 0   1  Alice  2022-01-01
# 1   2  Braga  2022-02-02
# 2   3  Steve  2022-03-03

# %%
# append write with Avro instead of Parquet
df.write \
    .option("write-format", "avro") \
    .option("snapshot-property.key", "value") \
    .insertInto("mydb.users")

# %%
# To show table history:
spark.sql("SELECT * FROM mydb.users.history").toPandas()
# Out:
#           made_current_at          snapshot_id     parent_id  \
# 0 2024-08-13 18:34:14.586  3711599203814133704           NaN
# 1 2024-08-13 18:35:13.989  4735134423970272370  3.711599e+18
#
#    is_current_ancestor
# 0                 True
# 1                 True

# %%
# To show table metadata log entries:
spark.sql("SELECT * FROM mydb.users.metadata_log_entries").toPandas()
# Out:
#                 timestamp                                               file  \
# 0 2024-08-13 18:34:04.153  s3a://my-bucket/iceberg/mydb/users/metadata/v1...
# 1 2024-08-13 18:34:14.586  s3a://my-bucket/iceberg/mydb/users/metadata/v2...
# 2 2024-08-13 18:35:13.989  s3a://my-bucket/iceberg/mydb/users/metadata/v3...
#
#    latest_snapshot_id  latest_schema_id  latest_sequence_number
# 0                 NaN               NaN                     NaN
# 1        3.711599e+18               0.0                     1.0
# 2        4.735134e+18               0.0                     2.0

# %%
# To show the valid snapshots for a table:
spark.sql("SELECT * FROM mydb.users.snapshots").toPandas()
# Out:
#              committed_at          snapshot_id     parent_id operation  \
# 0 2024-08-13 18:34:14.586  3711599203814133704           NaN    append
# 1 2024-08-13 18:35:13.989  4735134423970272370  3.711599e+18    append
#
#                                        manifest_list  \
# 0  s3a://my-bucket/iceberg/mydb/users/metadata/sn...
# 1  s3a://my-bucket/iceberg/mydb/users/metadata/sn...
#
#                                              summary
# 0  {'engine-version': '3.5.1', 'added-data-files'...
# 1  {'engine-version': '3.5.1', 'added-data-files'...

# %%
# To show all the table's current manifest entries for both data and delete files.
spark.sql("SELECT * FROM mydb.users.entries").toPandas()
# Out:
#    status          snapshot_id  sequence_number  file_sequence_number  \
# 0       1  4735134423970272370                2                     2
# 1       1  4735134423970272370                2                     2
# 2       1  3711599203814133704                1                     1
# 3       1  3711599203814133704                1                     1
#
#                                            data_file  \
# 0  (0, s3a://my-bucket/iceberg/mydb/users/data/00...
# 1  (0, s3a://my-bucket/iceberg/mydb/users/data/00...
# 2  (0, s3a://my-bucket/iceberg/mydb/users/data/00...
# 3  (0, s3a://my-bucket/iceberg/mydb/users/data/00...
#
#                                     readable_metrics
# 0  ((None, None, None, None, None, None), (None, ...
# 1  ((None, None, None, None, None, None), (None, ...
# 2  ((42, 1, 0, None, 1, 1), (47, 1, 0, None, Alic...
# 3  ((46, 2, 0, None, 2, 3), (56, 2, 0, None, Brag...

# %%
# To show a table's current files:
spark.sql("SELECT * FROM mydb.users.files").toPandas()
# Out:
#    content                                          file_path file_format  \
# 0        0  s3a://my-bucket/iceberg/mydb/users/data/00000-...        AVRO
# 1        0  s3a://my-bucket/iceberg/mydb/users/data/00001-...        AVRO
# 2        0  s3a://my-bucket/iceberg/mydb/users/data/00000-...     PARQUET
# 3        0  s3a://my-bucket/iceberg/mydb/users/data/00001-...     PARQUET
#
#    spec_id  record_count  file_size_in_bytes           column_sizes  \
# 0        0             1                 592                   None
# 1        0             2                 605                   None
# 2        0             1                 890  {1: 42, 2: 47, 3: 42}
# 3        0             2                 893  {1: 46, 2: 56, 3: 46}
#
#          value_counts   null_value_counts nan_value_counts  \
# 0                None                None             None
# 1                None                None             None
# 2  {1: 1, 2: 1, 3: 1}  {1: 0, 2: 0, 3: 0}               {}
# 3  {1: 2, 2: 2, 3: 2}  {1: 0, 2: 0, 3: 0}               {}
#
#                                         lower_bounds  \
# 0                                               None
# 1                                               None
# 2  {1: [1, 0, 0, 0], 2: [65, 108, 105, 99, 101], ...
# 3  {1: [2, 0, 0, 0], 2: [66, 114, 97, 103, 97], 3...
#
#                                         upper_bounds key_metadata  \
# 0                                               None         None
# 1                                               None         None
# 2  {1: [1, 0, 0, 0], 2: [65, 108, 105, 99, 101], ...         None
# 3  {1: [3, 0, 0, 0], 2: [83, 116, 101, 118, 101],...         None
#
#   split_offsets equality_ids  sort_order_id  \
# 0          None         None              0
# 1          None         None              0
# 2           [4]         None              0
# 3           [4]         None              0
#
#                                     readable_metrics
# 0  ((None, None, None, None, None, None), (None, ...
# 1  ((None, None, None, None, None, None), (None, ...
# 2  ((42, 1, 0, None, 1, 1), (47, 1, 0, None, Alic...
# 3  ((46, 2, 0, None, 2, 3), (56, 2, 0, None, Brag...

# %%
# To show a table's current file manifests:
spark.sql("SELECT * FROM mydb.users.manifests").toPandas()
# Out:
#    content                                               path  length  \
# 0        0  s3a://my-bucket/iceberg/mydb/users/metadata/4e...    6788
# 1        0  s3a://my-bucket/iceberg/mydb/users/metadata/6a...    6872
#
#    partition_spec_id    added_snapshot_id  added_data_files_count  \
# 0                  0  4735134423970272370                       2
# 1                  0  3711599203814133704                       2
#
#    existing_data_files_count  deleted_data_files_count  \
# 0                          0                         0
# 1                          0                         0
#
#    added_delete_files_count  existing_delete_files_count  \
# 0                         0                            0
# 1                         0                            0
#
#    deleted_delete_files_count partition_summaries
# 0                           0                  []
# 1                           0                  []

# %%
# To show a table's known snapshot references:
spark.sql("SELECT * FROM mydb.users.refs").toPandas()
# Out:
#    name    type          snapshot_id  max_reference_age_in_ms  \
# 0  main  BRANCH  4735134423970272370                      NaN
#
#    min_snapshots_to_keep  max_snapshot_age_in_ms
# 0                    NaN                     NaN

# %% [markdown]
# ### Time Travel

# %%
# time travel to snapshot with ID 4735134423970272370
spark.read
    .option("snapshot-id", 4735134423970272370)
    .format("iceberg")
    .load("path/to/table")

# time travel to October 26, 1986 at 01:21:00
spark.read
    .option("as-of-timestamp", "499162860000")
    .format("iceberg")
    .load("path/to/table")

# %%
spark.read.option("snapshot-id", 4735134423970272370).table("mydb.users").toPandas()
# Out:
#    id   name  updated_at
# 0   1  Alice  2022-01-01
# 1   1  Alice  2022-01-01
# 2   2  Braga  2022-02-02
# 3   3  Steve  2022-03-03
# 4   2  Braga  2022-02-02
# 5   3  Steve  2022-03-03

# %%
spark.read.option("snapshot-id", 3711599203814133704).table("mydb.users").toPandas()
# Out:
#    id   name  updated_at
# 0   1  Alice  2022-01-01
# 1   2  Braga  2022-02-02
# 2   3  Steve  2022-03-03

# %%
"""
-- time travel to October 26, 1986 at 01:21:00
SELECT * FROM prod.db.table TIMESTAMP AS OF '1986-10-26 01:21:00';

-- time travel to snapshot with id 10963874102873L
SELECT * FROM prod.db.table VERSION AS OF 10963874102873;

-- time travel to the head snapshot of audit-branch
SELECT * FROM prod.db.table VERSION AS OF 'audit-branch';

-- time travel to the snapshot referenced by the tag historical-snapshot
SELECT * FROM prod.db.table VERSION AS OF 'historical-snapshot';

"""

# %%
spark.sql("SELECT * FROM mydb.users TIMESTAMP AS OF '2024-08-13 18:35:00'").toPandas()
# Out:
#    id   name  updated_at
# 0   1  Alice  2022-01-01
# 1   2  Braga  2022-02-02
# 2   3  Steve  2022-03-03

# %%
spark.sql("SELECT * FROM mydb.users VERSION AS OF 3711599203814133704").toPandas()
# Out:
#    id   name  updated_at
# 0   1  Alice  2022-01-01
# 1   2  Braga  2022-02-02
# 2   3  Steve  2022-03-03

# %%
spark.table("mydb.users").toPandas()
# Out:
#    id   name  updated_at
# 0   1  Alice  2022-01-01
# 1   2  Braga  2022-02-02
# 2   3  Steve  2022-03-03
# 3   1  Alice  2022-01-01
# 4   2  Braga  2022-02-02
# 5   3  Steve  2022-03-03

# %%
spark.read.format("iceberg").load("mydb.users").toPandas()
# Out:
#    id   name  updated_at
# 0   1  Alice  2022-01-01
# 1   2  Braga  2022-02-02
# 2   3  Steve  2022-03-03
# 3   1  Alice  2022-01-01
# 4   2  Braga  2022-02-02
# 5   3  Steve  2022-03-03
